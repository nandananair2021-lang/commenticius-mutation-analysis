# %%
import os
print(os.listdir())
# Out:
# ['.pythonstartup.py', '.config', '.gitconfig', '.ipython', 'Untitled.ipynb', '.virtualenvs', 'Untitled1.ipynb', '.ipynb_checkpoints', '.anaconda', '.jupyter', 'Untitled5.ipynb', '.profile', '.conda', '.npm', 'Untitled4.ipynb', 'Untitled3.ipynb', 'anaconda_projects', '.local', 'Untitled6.ipynb', 'README.ipynb', 'Untitled2.ipynb', '.cache', '.bashrc', '.vimrc']
